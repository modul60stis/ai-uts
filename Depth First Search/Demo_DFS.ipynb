# %%
# Import Library
import pandas as pd

# Import Data
data = pd.read_csv("https://raw.githubusercontent.com/melaniewalsh/sample-social-network-datasets/master/sample-datasets/modernist-journals-project/crisis/crisis-edges.csv", delimiter=',')

# %%
# Menampilkan Data
data
# Out:
#                        Source                     Target  Weight
# 0          Latimer, Louise R.   Johnson, Georgia Douglas       2
# 1              Allison, M. G.       Allison, Madeline G.       2
# 2              Allison, M. G.  Jordan, Winifred Virginia       2
# 3              Allison, M. G.          Du Bois, W. E. B.       2
# 4                 Hurst, John           Bohanan, Otto L.       2
# ..                        ...                        ...     ...
# 268          Hughes, Langston         Newsome, Effie Lee       4
# 269          Hughes, Langston              McKay, Claude       2
# 270   Russell, Charles Edward   Villard, Oswald Garrison       3
# 271  Villard, Oswald Garrison                   Scurlock       2
# 272         Brawley, Benjamin         Watkins, Lucian B.       2
#
# [273 rows x 3 columns]

# %%
# Import Dictionary for Graph
from collections import defaultdict

# Function untuk menambahkan edge (sisi) pada Graph
graph = defaultdict(list)
def addEdge(graph, u, v):
  graph[u].append(v)

# Definition of Function
def generate_edges(graph):
  edges = []
  # for each node in graph (untuk setiap node dalam graph)
  for node in graph:
    # for each neighbour node of single node (untuk setiap node tetangga pada node tunggal)
    for neighbour in graph[node]:
      # if edge exists then append (jika edge ada maka tambahkan)
      edges.append((node, neighbour))
  return edges

# Declaration of graph as dictionary
for i in range(len(data)):
  addEdge(graph, data["Source"][i], data["Target"][i]) #menambahkan edge antara 2 node, yaitu Source dan Target

# %%
# Print Generated Edges Graph
print(generate_edges(graph))
# Out:
# [('Latimer, Louise R.', 'Johnson, Georgia Douglas'), ('Allison, M. G.', 'Allison, Madeline G.'), ('Allison, M. G.', 'Jordan, Winifred Virginia'), ('Allison, M. G.', 'Du Bois, W. E. B.'), ('Hurst, John', 'Bohanan, Otto L.'), ('Hurst, John', 'Villard, Oswald Garrison'), ('Hurst, John', 'Johnson, James Weldon'), ('Hurst, John', 'Fauset, Jessie'), ('Hurst, John', 'Storey, Moorfield'), ('Hurst, John', 'Du Bois, W. E. B.'), ('Hurst, John', 'Johnson, Georgia Douglas'), ('Lindsay, Nicholas Vachel', 'Spingarn, J. E.'), ('Stafford, Wendell Phillips', 'Adams, John Henry'), ('Moore, William', 'Johnson, Fenton'), ('Johnson, Fenton', 'Villard, Oswald Garrison'), ('Johnson, Fenton', 'Brockman, W. L.'), ('Johnson, Fenton', 'Corrothers, James D.'), ('Brown and Dawson', 'Du Bois, W. E. B.'), ('Du Bois, W. E. B.', 'J. F.'), ('Du Bois, W. E. B.', 'Bohanan, Otto L.'), ('Du Bois, W. E. B.', 'Scurlock'), ('Du Bois, W. E. B.', 'Jordan, Winifred Virginia'), ('Du Bois, W. E. B.', 'Cotter, Joseph S.'), ('Du Bois, W. E. B.', 'Villard, Oswald Garrison'), ('Du Bois, W. E. B.', 'Brown, Richard L.'), ('Du Bois, W. E. B.', 'Bagnall, Robert W.'), ('Du Bois, W. E. B.', 'Ovington, Mary W.'), ('Du Bois, W. E. B.', 'Fawcett, James Waldo'), ('Du Bois, W. E. B.', 'Frazier, C. Emily'), ('Du Bois, W. E. B.', 'Lee, Mary Effie'), ('Du Bois, W. E. B.', 'Underwood and Underwood'), ('Du Bois, W. E. B.', 'Chesnutt, Charles W.'), ('Du Bois, W. E. B.', 'Rogers, Lucille'), ('Du Bois, W. E. B.', 'Jordan, L. G.'), ('Du Bois, W. E. B.', 'Watkins, Lucian B.'), ('Du Bois, W. E. B.', 'Johnson, Georgia Douglas'), ('Du Bois, W. E. B.', 'Richardson, Willis'), ('Du Bois, W. E. B.', 'Newsome, Effie Lee'), ('Du Bois, W. E. B.', 'Pickens, William'), ('Du Bois, W. E. B.', 'Allison, Madeline G.'), ('Du Bois, W. E. B.', 'Spencer, Anne'), ('Du Bois, W. E. B.', 'Burch, Charles Eaton'), ('Du Bois, W. E. B.', 'Pendleton, Leila Amos'), ('Du Bois, W. E. B.', 'Brown, Edward O.'), ('Du Bois, W. E. B.', 'White, Walter F.'), ('Du Bois, W. E. B.', 'Hershaw, L. M.'), ('Du Bois, W. E. B.', 'Spingarn, J. E.'), ('Du Bois, W. E. B.', 'Stoddard, Yetta Kay'), ('Du Bois, W. E. B.', 'Wheeler, Laura'), ('Du Bois, W. E. B.', 'Adams, John Henry'), ('Du Bois, W. E. B.', 'Toomer, Jean'), ('Du Bois, W. E. B.', 'Clifford, Carrie W.'), ('Du Bois, W. E. B.', 'Hill, Leslie Pinckney'), ('Du Bois, W. E. B.', 'Moravsky, Maria'), ('Du Bois, W. E. B.', 'Russell, Charles Edward'), ('Du Bois, W. E. B.', 'Smith, Albert'), ('Du Bois, W. E. B.', 'Braithwaite, William Stanley'), ('Du Bois, W. E. B.', 'Canfield, Dorothy'), ('Du Bois, W. E. B.', 'Wilkinson, Hilda'), ('Du Bois, W. E. B.', 'Harris, Lorenzo'), ('Du Bois, W. E. B.', 'Hughes, Langston'), ('Du Bois, W. E. B.', 'McKay, Claude'), ('Du Bois, W. E. B.', 'Saunders, Vincent'), ('Du Bois, W. E. B.', 'Francique, John'), ('Du Bois, W. E. B.', 'Murray, Ella Rush'), ('Du Bois, W. E. B.', 'Walts, Frank'), ('Du Bois, W. E. B.', 'Johnson, Charles Bertram'), ('Du Bois, W. E. B.', 'Jones, Scipio'), ('Du Bois, W. E. B.', 'Johnson, James Weldon'), ('Du Bois, W. E. B.', 'Shillady, John R.'), ('Du Bois, W. E. B.', 'Fauset, Jessie'), ('Du Bois, W. E. B.', 'Jackson, May Howard'), ('Du Bois, W. E. B.', 'Cullen, Countee P.'), ('Du Bois, W. E. B.', 'Battey, C. M.'), ('Du Bois, W. E. B.', 'Battey'), ('Du Bois, W. E. B.', 'Bentley, Florence Lewis'), ('Du Bois, W. E. B.', 'Scott, William E.'), ('Du Bois, W. E. B.', 'Storey, Moorfield'), ('Harris, Lorenzo', 'Bohanan, Otto L.'), ('Harris, Lorenzo', 'Saunders, Vincent'), ('Harris, Lorenzo', 'Grimke, Archibald H.'), ('Harris, Lorenzo', 'Corrothers, James D.'), ('Harris, Lorenzo', 'Scott, William E.'), ('Harris, Lorenzo', 'Johnson, Georgia Douglas'), ('Harris, Lorenzo', 'Clarana, José'), ('Harris, Lorenzo', 'Pendleton, Leila Amos'), ('Harris, Lorenzo', 'Battey, C. M.'), ('Harris, Lorenzo', 'Storey, Moorfield'), ('Jones, Harry H.', 'Johnson, Georgia Douglas'), ('Koch, Felix J.', 'Johnson, Georgia Douglas'), ('Hill, Leslie Pinckney', 'Adams, John Henry'), (' ...

# %%
graph.keys()
# Out:
# dict_keys(['Latimer, Louise R.', 'Allison, M. G.', 'Hurst, John', 'Lindsay, Nicholas Vachel', 'Stafford, Wendell Phillips', 'Moore, William', 'Johnson, Fenton', 'Brown and Dawson', 'Du Bois, W. E. B.', 'Harris, Lorenzo', 'Jones, Harry H.', 'Koch, Felix J.', 'Hill, Leslie Pinckney', 'Clifford, Carrie W.', 'Toomer, Jean', 'Wheeler, Laura', 'Spingarn, J. E.', 'Bradford, George G.', 'Moravsky, Maria', 'Cloud, F. H.', 'Schomburg, Arthur A.', 'Jordan, L. G.', 'Rogers, Lucille', 'Lee, Mary Effie', 'Ovington, Mary W.', 'Dunbar-Nelson, Alice', 'Bentley, Florence Lewis', 'M. W. O.', 'Work, Monroe N.', 'Smith, Albert', 'Addams, Jane', 'Wilkinson, Hilda', 'Braithwaite, William Stanley', 'Johnson, James Weldon', 'Milholland, John E. (Mrs.)', 'White, Walter F.', 'Brown, Edward O.', 'Pendleton, Leila Amos', 'Adams, John Henry', 'Brooks, C. Ames', 'Henderson, Edwin B.', 'Johnson, Charles Bertram', 'Hunton, A. W.', 'Dill, A. G.', 'Shaw, Charles A.', 'Grimke, Archibald H.', 'Bohanan, Otto L.', 'Battey, C. M.', 'Cullen, Countee P.', 'Fauset, Jessie', 'Terrell, Mary Church', 'Saunders, Vincent', 'Talbert, Mary B.', 'Johnson, Georgia Douglas', 'Burch, Charles Eaton', 'Dickerman, G. S.', 'Pickens, William', 'Spencer, Anne', 'Chesnutt, Charles W.', 'Underwood and Underwood', 'Storey, Moorfield', 'Murray, Ella Rush', 'Allison, Madeline G.', 'Walts, Frank', 'Jones, Scipio', 'Hershaw, L. M.', 'Hughes, Langston', 'Russell, Charles Edward', 'Villard, Oswald Garrison', 'Brawley, Benjamin'])

# %%
# Print Generated Graph
graph
# Out:
# defaultdict(list,
#             {'Latimer, Louise R.': ['Johnson, Georgia Douglas'],
#              'Allison, M. G.': ['Allison, Madeline G.',
#               'Jordan, Winifred Virginia',
#               'Du Bois, W. E. B.'],
#              'Hurst, John': ['Bohanan, Otto L.',
#               'Villard, Oswald Garrison',
#               'Johnson, James Weldon',
#               'Fauset, Jessie',
#               'Storey, Moorfield',
#               'Du Bois, W. E. B.',
#               'Johnson, Georgia Douglas'],
#              'Lindsay, Nicholas Vachel': ['Spingarn, J. E.'],
#              'Stafford, Wendell Phillips': ['Adams, John Henry'],
#              'Moore, William': ['Johnson, Fenton'],
#              'Johnson, Fenton': ['Villard, Oswald Garrison',
#               'Brockman, W. L.',
#               'Corrothers, James D.'],
#              'Brown and Dawson': ['Du Bois, W. E. B.'],
#              'Du Bois, W. E. B.': ['J. F.',
#               'Bohanan, Otto L.',
#               'Scurlock',
#               'Jordan, Winifred Virginia',
#               'Cotter, Joseph S.',
#               'Villard, Oswald Garrison',
#               'Brown, Richard L.',
#               'Bagnall, Robert W.',
#               'Ovington, Mary W.',
#               'Fawcett, James Waldo',
#               'Frazier, C. Emily',
#               'Lee, Mary Effie',
#               'Underwood and Underwood',
#               'Chesnutt, Charles W.',
#               'Rogers, Lucille',
#               'Jordan, L. G.',
#               'Watkins, Lucian B.',
#               'Johnson, Georgia Douglas',
#               'Richardson, Willis',
#               'Newsome, Effie Lee',
#               'Pickens, William',
#               'Allison, Madeline G.',
#               'Spencer, Anne',
#               'Burch, Charles Eaton',
#               'Pendleton, Leila Amos',
#               'Brown, Edward O.',
#               'White, Walter F.',
#               'Hershaw, L. M.',
#               'Spingarn, J. E.',
#               'Stoddard, Yetta Kay',
#               'Wheeler, Laura',
#               'Adams, John Henry',
#               'Toomer, Jean',
#               'Clifford, Carrie W.',
#               'Hill, Leslie Pinckney',
#               'Moravsky, Maria',
#               'Russell, Charles Edward',
#               'Smith, Albert',
#               'Braithwaite, William Stanley',
#               'Canfield, Dorothy',
#               'Wilkinson, Hilda',
#               'Harris, Lorenzo',
#               'Hughes, Langston',
#               'McKay, Claude',
#               'Saunders, Vincent',
#               'Francique, John',
#               'Murray, Ella Rush',
#               'Walts, Frank',
#               'Johnson, Charles Bertram',
#               'Jones, Scipio',
#               'Johnson, James Weldon',
#               'Shillady, John R.',
#               'Fauset, Jessie',
#               'Jackson, May Howard',
#               'Cullen, Countee P.',
#               'Battey, C. M.',
#               'Battey',
#               'Bentley, Florence Lewis',
#               'Scott, William E.',
#               'Storey, Moorfield'],
#              'Harris, Lorenzo': ['Bohanan, Otto L.',
#               'Saunders, Vincent',
#               'Grimke, Archibald H.',
#               'Corrothers, James D.',
#               'Scott, William E.',
#               'Johnson, Georgia Douglas',
#               'Clarana, José',
#               'Pendleton, Leila Amos',
#               'Battey, C. M.',
#               'Storey, Moorfield'],
#              'Jones, Harry H.': ['Johnson, Georgia Douglas'],
#              'Koch, Felix J.': ['Johnson, Georgia Douglas'],
#              'Hill, Leslie Pinckney': ['Adams, John Henry',
#               'Fauset, Jessie',
#               'Storey, Moorfield'],
#              'Clifford, Carrie W.': ['Brawley, Benjamin',
#               'Fauset, Jessie',
#               'Allison, Madeline G.',
#               'Battey, C. M.'],
#              'Toomer, Jean': ['Newsome, Effie Lee', 'Allison, Madeline G.'],
#              'Wheeler, Laura': ['Dunbar-Nelson, Alice',
#               'Cotter, Joseph S.',
#               'Russell, Charles Edward',
#               'Smith, Albert',
#               'Johnson, James Weldon',
#               'Canfield, Dorothy',
#               'Saunders, Vincent',
#               'Johnson, Georgia Douglas',
#               'Lee, Mary Effie',
#               'Allison, Madeline G.',
#               'Fauset, Jessie',
#               'Battey, C. M.',
#               'Johnson, Charles Bertram',
#               'Walts, Frank'],
#              'Spingarn, J. E.': ['Villard, Oswald Garrison',
#               'Cloud, F. H.',
#               'Johnson, Georgia Douglas',
#               'Johnson, James Weldon',
#               'Fauset, Jessie',
#               'Ovington, Mary W.',
#               'Storey, Moorfield',
#               'Watkins, Lucian B.',
#               'Bradford, George G.'],
#              'Bradford, George G.': ['Watkins, Lucian B.',
#               'Johnson, Georgia Douglas'],
#              'Moravsky, Maria': ['Allison, Madeline G.', 'Wilkinson, Hilda'],
#              'Cloud, F. H.': ['Johnson, Georgia Douglas'],
#              'Schomburg, Arthur A.': ['Villard, Oswald Garrison',
#               'Dickerman, G. S.'],
#              'Jordan, L. G.': ['Allison, Madeline G.',
#               'Fauset, Jessie',
#               'Hughes, Langston'],
#              'Rogers, Lucille': ['Allison, Madeline G.', 'Fauset, Jessie'],
#              'Lee, Mary Effie': ['Allison, Madeline G.',
#               'Underwood and Underwood',
#               'Scurlock',
#               'Fauset, Jessie'],
#              'Ovington, Mary W.': ['Allison, Madeline G.',
#               'Hughes, Langston',
#               'Johnson, Georgia Douglas'],
#              'Dunbar-Nelson, Alice': ['Johnson, Georgia Douglas'],
#              'Bentley, Florence Lewis': ['Wilkinson, Hilda',
#               'Johnson, Charles Bertram',
#               'Allison, Madeline G.'],
#              'M. W. O.': ['Villard, Oswald Garrison', 'Fauset, Jessie'],
#              'Work, Monroe N.': ['Johnson, Georgia Douglas'],
#              'Smith, Albert': ['Walts, Frank',
#               'Pickens, William',
#               'Allison, Madeline G.',
#               'Fauset, Jessie',
#               'Spencer, Anne'],
#              'Addams, Jane': ['Adams, John Henry'],
#              'Wilkinson, Hilda': ['Walts, Frank',
#               'Allison, Madeline G.',
#               'Burch, Charles Eaton',
#               'Fauset, Jessie',
#               'Johnson, Charles Bertram',
#               'Murray, Ella Rush'],
#              'Braithwaite, William Stanley': ['Villard, Oswald Garrison',
#               'Brown, Richard L.',
#               'Russell, Charles Edward',
#               'Chesnutt, Charles W.',
#               'Hershaw, L. M.'],
#              'Johnson, James Weldon': ['Bohanan, Otto L.',
#               'Hughes, Langston',
#               'Scurlock',
#               'Fauset, Jessie',
#               'Allison, Madeline G.'],
#              'Milholland, John E. (Mrs.)': ['Adams, John Henry'],
#              'White, Walter F.': ['Walts, Frank',
#               'Steward, T. G.',
#               'Allison, Madeline G.',
#               'Johnson, Georgia Douglas'],
#              'Brown, Edward O.': ['Villard, Oswald Garrison'],
#              'Pendleton, Leila Amos': ['Allison, Madeline G.',
#               'Fauset, Jessie',
#               'Bohanan, Otto L.'],
#              'Adams, John Henry': ['Villard, Oswald Garrison',
#               'Allison, Madeline G.',
#               'Fauset, Jessie',
#               'Hershaw, L. M.'],
#              'Brooks, C. Ames': ['Hershaw, L. M.'],
#              'Henderson, Edwin B.': ['Bohanan, Otto L.'],
#              'Johnson, Charles Bertram': ['Allison, Madeline G.',
#               'Fauset, Jessie'],
#              'Hunton, A. W.': ['Dickerman, G. S.'],
#              'Dill, A. G.': ['Johnson, Georgia Douglas'],
#              'Shaw, Charles A.': ['Saunders, Vincent'],
#              'Grimke, Archibald H.': ['Corrothers, James D.'],
#              'Bohanan, Otto L.': ['Scurlock',
#               'Steward, T. G.',
#               'Watkins, Lucian B.',
#               'Storey, Moorfield'],
#              'Battey, C. M.': ['Storey, Moorfield',
#               'Allison, Madeline G.',
#               'Fauset, Jessie'],
#              'Cullen, Countee P.': ['Francique, John',
#               'Allison, Madeline G.',
#               'Fauset, Jessie'],
#              'Fauset, Jessie': ['Scurlock',
#               'Cotter, Joseph S.',
#               'Newsome, Effie Lee',
#               'Underwood and Underwood',
#               'Francique, John',
#               'Johnson, Georgia Douglas',
#               'Allison, Madeline G.',
#               'Brown, Richard L.',
#               'Dickerman, G. S.',
#               'Villard, Oswald Garrison',
#               'Russell, Charles Edward',
#               'Fawcett, James Waldo',
#               'Canfield, Dorothy',
#               'Hughes, Langston',
#               'Hershaw, L. M.',
#               'Walts, Frank',
#               'Jones, Scipio',
#               'Jackson, May Howard'],
#              'Terrell, Mary Church': ['Hershaw, L. M.'],
#              'Saunders, Vincent': ['Villard, Oswald Garrison',
#               'Bagnall, Robert W.',
#               'Scott, William E.',
#               'Watkins, Lucian B.',
#               'Johnson, Georgia Douglas'],
#              'Talbert, Mary B.': ['Johnson, Georgia Douglas'],
#              'Johnson, Georgia Douglas': ['Newsome, Effie Lee',
#               'Underwood and Underwood',
#               'Scurlock',
#               'Watkins, Lucian B.',
#               'Steward, T. G.',
#               'Walts, Frank',
#               'Carter, George R.',
#               'Hughes, Langston',
#               'Lewin, Rose Dorothy',
#               'Allison, Madeline G.',
#               'Storey, Moorfield'],
#              'Burch, Charles Eaton': ['Allison, Madeline G.'],
#              'Dickerman, G. S.': ['Villard, Oswald Garrison'],
#              'Pickens, William': ['Allison, Madeline G.'],
#              'Spencer, Anne': ['Allison, Madeline G.', 'Walts, Frank'],
#              'Chesnutt, Charles W.': ['Villard, Oswald Garrison',
#               'Brown, Richard L.',
#               'Brawley, Benjamin',
#               'Hershaw, L. M.'],
#              'Underwood and Underwood': ['Brawley, Benjamin',
#               'Allison, Madeline G.',
#               'Walts, Frank'],
#              'Storey, Moorfield': ['Villard, Oswald Garrison'],
#              'Murray, Ella Rush': ['Allison, Madeline G.'],
#              'Allison, Madeline G.': ['J. F.',
#               'Jordan, Winifred Virginia',
#               'Cotter, Joseph S.',
#               'Bagnall, Robert W.',
#               'Fawcett, James Waldo',
#               'Newsome, Effie Lee',
#               'Stoddard, Yetta Kay',
#               'Canfield, Dorothy',
#               'Hughes, Langston',
#               'McKay, Claude',
#               'Francique, John',
#               'Walts, Frank',
#               'Jones, Scipio'],
#              'Walts, Frank': ['Holmes, John Haynes'],
#              'Jones, Scipio': ['Hughes, Langston'],
#              'Hershaw, L. M.': ['Villard, Oswald Garrison'],
#              'Hughes, Langston': ['Fawcett, James Waldo',
#               'Newsome, Effie Lee',
#               'McKay, Claude'],
#              'Russell, Charles Edward': ['Villard, Oswald Garrison'],
#              'Villard, Oswald Garrison': ['Scurlock'],
#              'Brawley, Benjamin': ['Watkins, Lucian B.']})

# %%
# Membuat Fungsi DFS
def DFS(start, goal, path, level):
    print('\nLevel saat ini -->', level)
    print('Node tujuan untuk diuji', start)
    path.append(start)
    if start==goal:
        print('Goal test berhasil')
        return path
    print('Goal node test gagal')
    print('\nNode saat ini',start)
    for child in graph[start]:
        if DFS(child,goal,path,level+1):
            return path
        path.pop()
    return False

start = input('Start node: ') # Allison, M. G.
goal = input('Masukkan Tujuan : ') # Scurlock
print()
path = list()
res = DFS(start,goal,path,0)
if(res):
    print("Jalur ke goal telah ditemukan")
    print("path", path)
else:
    print("Tidak terdapat jalur yang ditemukan untuk batas kedalaman yang telah ditentukan")
# Out:
# Start node: Allison, M. G.
# Masukkan Tujuan : Scurlock
#
#
# Level saat ini --> 0
# Node tujuan untuk diuji Allison, M. G.
# Goal node test gagal
#
# Node saat ini Allison, M. G.
#
# Level saat ini --> 1
# Node tujuan untuk diuji Allison, Madeline G.
# Goal node test gagal
#
# Node saat ini Allison, Madeline G.
#
# Level saat ini --> 2
# Node tujuan untuk diuji J. F.
# Goal node test gagal
#
# Node saat ini J. F.
#
# Level saat ini --> 2
# Node tujuan untuk diuji Jordan, Winifred Virginia
# Goal node test gagal
#
# Node saat ini Jordan, Winifred Virginia
#
# Level saat ini --> 2
# Node tujuan untuk diuji Cotter, Joseph S.
# Goal node test gagal
#
# Node saat ini Cotter, Joseph S.
#
# Level saat ini --> 2
# Node tujuan untuk diuji Bagnall, Robert W.
# Goal node test gagal
#
# Node saat ini Bagnall, Robert W.
#
# Level saat ini --> 2
# Node tujuan untuk diuji Fawcett, James Waldo
# Goal node test gagal
#
# Node saat ini Fawcett, James Waldo
#
# Level saat ini --> 2
# Node tujuan untuk diuji Newsome, Effie Lee
# Goal node test gagal
#
# Node saat ini Newsome, Effie Lee
#
# Level saat ini --> 2
# Node tujuan untuk diuji Stoddard, Yetta Kay
# Goal node test gagal
#
# Node saat ini Stoddard, Yetta Kay
#
# Level saat ini --> 2
# Node tujuan untuk diuji Canfield, Dorothy
# Goal node test gagal
#
# Node saat ini Canfield, Dorothy
#
# Level saat ini --> 2
# Node tujuan untuk diuji Hughes, Langston
# Goal node test gagal
#
# Node saat ini Hughes, Langston
#
# Level saat ini --> 3
# Node tujuan untuk diuji Fawcett, James Waldo
# Goal node test gagal
#
# Node saat ini Fawcett, James Waldo
#
# Level saat ini --> 3
# Node tujuan untuk diuji Newsome, Effie Lee
# Goal node test gagal
#
# Node saat ini Newsome, Effie Lee
#
# Level saat ini --> 3
# Node tujuan untuk diuji McKay, Claude
# Goal node test gagal
#
# Node saat ini McKay, Claude
#
# Level saat ini --> 2
# Node tujuan untuk diuji McKay, Claude
# Goal node test gagal
#
# Node saat ini McKay, Claude
#
# Level saat ini --> 2
# Node tujuan untuk diuji Francique, John
# Goal node test gagal
#
# Node saat ini Francique, John
#
# Level saat ini --> 2
# Node tujuan untuk diuji Walts, Frank
# Goal node test gagal
#
# Node saat ini Walts, Frank
#
# Level saat ini --> 3
# Node tujuan untuk diuji Holmes, John Haynes
# Goal node test gagal
#
# Node saat ini Holmes, John Haynes
#
# Level saat ini --> 2
# Node tujuan untuk diuji Jones, Scipio
# Goal node test gagal
#
# Node saat ini Jones, Scipio
#
# Level saat ini --> 3
# Node tujuan untuk diuji Hughes, Langston
# Goal node test gagal
#
# Node saat ini Hughes, Langston
#
# Level saat ini --> 4
# Node tujuan untuk diuji Fawcett, James Waldo
# Goal node test gagal
#
# Node saat ini Fawcett, James Waldo
#
# Level saat ini --> 4
# Node tujuan untuk diuji Newsome, Effie Lee
# Goal node test gagal
#
# Node saat ini Newsome, Effie Lee
#
# Level saat ini --> 4
# Node tujuan untuk diuji McKay, Claude
# Goal node test gagal
#
# Node saat ini McKay, Claude
#
# Level saat ini --> 1
# Node tujuan untuk diuji Jordan, Winifred Virginia
# Goal node test gagal
#
# Node saat ini Jordan, Winifred Virginia
#
# Level saat ini --> 1
# Node tujuan untuk diuji Du Bois, W. E. B.
# Goal node test gagal
#
# Node saat ini Du Bois, W. E. B.
#
# Level saat ini --> 2
# Node tujuan untuk diuji J. F.
# Goal node test gagal
#
# Node saat ini J. F.
#
# Level saat ini --> 2
# Node tujuan untuk diuji Bohanan, Otto L.
# Goal node test gagal
#
# Node saat ini Bohanan, Otto L.
#
# Level saat ini --> 3
# Node tujuan untuk diuji Scurlock
# Goal test berhasil
# Jalur ke goal telah ditemukan
# path ['Allison, M. G.', 'Du Bois, W. E. B.', 'Bohanan, Otto L.', 'Scurlock']

# %%
# Visualisasi Graph
#!pip install ipywidgets
#!pip install ipympl

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %matplotlib widget

G = nx.Graph()

for i in range(len(data)):
  G.add_edge(data["Source"][i], data["Target"][i])

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 96
# Number of edges: 273
# Average degree:   5.6875

# %%
plt.figure()
nx.draw(G, with_labels = 1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
